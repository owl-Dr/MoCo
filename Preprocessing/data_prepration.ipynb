# %%
import numpy as np
import pandas as pd

# kaggle imdb dataset
# https://www.kaggle.com/datasets/carolzhangdc/imdb-5000-movie-dataset

movies=pd.read_csv('tmdb_5000_movies.csv')
credits=pd.read_csv('tmdb_5000_credits.csv')

# %% [markdown]
# #### Overview of data

# %%
movies.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
credits.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# ...

# %% [markdown]
# #### Merging them into one dataframe , join on the basis on coloumn title

# %%
movies=movies.merge(credits,on='title')

# %% [markdown]
# #### Feature Selection

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4809 entries, 0 to 4808
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4809 non-null   int64
#  1   genres                4809 non-null   object
#  2   homepage              1713 non-null   object
#  3   id                    4809 non-null   int64
#  4   keywords              4809 non-null   object
#  5   original_language     4809 non-null   object
#  6   original_title        4809 non-null   object
#  7   overview              4806 non-null   object
#  8   popularity            4809 non-null   float64
#  9   production_companies  4809 non-null   object
#  10  production_countries  4809 non-null   object
#  11  release_date          4808 non-null   object
#  12  revenue               4809 non-null   int64
#  13  runtime               4807 non-null   float64
#  14  spoken_languages      4809 non-null   object
# ...

# %%
selected_columns = ['movie_id','genres', 'popularity','vote_average', 'vote_count','title','cast','crew','overview','keywords']
# Create a new DataFrame with selected columns
movies = movies[selected_columns]

# %%
#missing data
movies.isnull().sum()
# Out:
# movie_id        0
# genres          0
# popularity      0
# vote_average    0
# vote_count      0
# title           0
# cast            0
# crew            0
# overview        3
# keywords        0
# dtype: int64

# %%
movies.dropna(inplace=True)

# %%
import ast
def convert(text):
    L = []
    for i in ast.literal_eval(text):
        L.append(i['name']) 
    return L 
movies['genres'] = movies['genres'].apply(convert)
movies.head()
# Out:
#    movie_id                                         genres  popularity  \
# 0     19995  [Action, Adventure, Fantasy, Science Fiction]  150.437577
# 1       285                   [Adventure, Fantasy, Action]  139.082615
# 2    206647                     [Action, Adventure, Crime]  107.376788
# 3     49026               [Action, Crime, Drama, Thriller]  112.312950
# 4     49529           [Action, Adventure, Science Fiction]   43.926995
#
#    vote_average  vote_count                                     title  \
# 0           7.2       11800                                    Avatar
# 1           6.9        4500  Pirates of the Caribbean: At World's End
# 2           6.3        4466                                   Spectre
# 3           7.6        9106                     The Dark Knight Rises
# 4           6.1        2124                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# ...

# %%
movies['keywords'] = movies['keywords'].apply(convert)
movies.head()
# Out:
#    movie_id                                         genres  popularity  \
# 0     19995  [Action, Adventure, Fantasy, Science Fiction]  150.437577
# 1       285                   [Adventure, Fantasy, Action]  139.082615
# 2    206647                     [Action, Adventure, Crime]  107.376788
# 3     49026               [Action, Crime, Drama, Thriller]  112.312950
# 4     49529           [Action, Adventure, Science Fiction]   43.926995
#
#    vote_average  vote_count                                     title  \
# 0           7.2       11800                                    Avatar
# 1           6.9        4500  Pirates of the Caribbean: At World's End
# 2           6.3        4466                                   Spectre
# 3           7.6        9106                     The Dark Knight Rises
# 4           6.1        2124                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# ...

# %%
def convert_cast(text):
    L = []
    counter = 0
    for i in ast.literal_eval(text):
        L.append(i['name'])
        counter += 1
        if counter == 5:
            break
    return L
movies['cast'] = movies['cast'].apply(convert_cast)
movies.head()
# Out:
#    movie_id                                         genres  popularity  \
# 0     19995  [Action, Adventure, Fantasy, Science Fiction]  150.437577
# 1       285                   [Adventure, Fantasy, Action]  139.082615
# 2    206647                     [Action, Adventure, Crime]  107.376788
# 3     49026               [Action, Crime, Drama, Thriller]  112.312950
# 4     49529           [Action, Adventure, Science Fiction]   43.926995
#
#    vote_average  vote_count                                     title  \
# 0           7.2       11800                                    Avatar
# 1           6.9        4500  Pirates of the Caribbean: At World's End
# 2           6.3        4466                                   Spectre
# 3           7.6        9106                     The Dark Knight Rises
# 4           6.1        2124                               John Carter
#
#                                                 cast  \
# 0  [Sam Worthington, Zoe Saldana, Sigourney Weave...
# ...

# %%
def fetch_director(text):
    L = []
    for i in ast.literal_eval(text):
        if i['job']=='Director':
            L.append(i['name'])
            break
    return L
movies['crew']=movies['crew'].apply(fetch_director)
movies.head()
# Out:
#    movie_id                                         genres  popularity  \
# 0     19995  [Action, Adventure, Fantasy, Science Fiction]  150.437577
# 1       285                   [Adventure, Fantasy, Action]  139.082615
# 2    206647                     [Action, Adventure, Crime]  107.376788
# 3     49026               [Action, Crime, Drama, Thriller]  112.312950
# 4     49529           [Action, Adventure, Science Fiction]   43.926995
#
#    vote_average  vote_count                                     title  \
# 0           7.2       11800                                    Avatar
# 1           6.9        4500  Pirates of the Caribbean: At World's End
# 2           6.3        4466                                   Spectre
# 3           7.6        9106                     The Dark Knight Rises
# 4           6.1        2124                               John Carter
#
#                                                 cast                 crew  \
# ...

# %%
movies['overview']=movies['overview'].apply(lambda x:x.split())

# %%
movies['genres']=movies['genres'].apply(lambda x:[i.replace(" ","") for i in x])
movies['keywords']=movies['keywords'].apply(lambda x:[i.replace(" ","") for i in x])
movies['cast']=movies['cast'].apply(lambda x:[i.replace(" ","") for i in x])
movies['crew']=movies['crew'].apply(lambda x:[i.replace(" ","") for i in x])

# %% [markdown]
# #### Processed Dataset

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4806 entries, 0 to 4808
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   movie_id      4806 non-null   int64
#  1   genres        4806 non-null   object
#  2   popularity    4806 non-null   float64
#  3   vote_average  4806 non-null   float64
#  4   vote_count    4806 non-null   int64
#  5   title         4806 non-null   object
#  6   cast          4806 non-null   object
#  7   crew          4806 non-null   object
#  8   overview      4806 non-null   object
#  9   keywords      4806 non-null   object
# dtypes: float64(2), int64(2), object(6)
# memory usage: 413.0+ KB

# %%
movies.to_csv('data.csv')
